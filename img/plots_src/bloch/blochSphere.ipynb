# %% [markdown]
# # Create maps for representing Bloch spheres

# %% [markdown]
# For that I'll use the Husimi distribution of totally polarized states poinitg onto some direction $\bf{n}$
# $$Q(\phi,\theta) = \frac{1}{2\pi} \langle Nj |_{\bf{n}} \varrho | Nj \rangle_{\bf{n}}$$

# %% [markdown]
# ## Load libraries

# %%
using HDF5, PyPlot
using BasicQuIn

# functions to generate the map
include("blochSphere.jl");
# Out:
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# in pystring_query at /home/iapellaniz/.julia/v0.5/PyCall/src/conversions.jl
# sys:1: PyGIWarning: Gtk was imported without specifying a version first. Use gi.require_version('Gtk', '3.0') before import to ensure that the right version gets loaded.

# %% [markdown]
# Function to generate map data

# %% [markdown]
# ## Generate map

# %% [markdown]
# The function `generateMap()` takes 3 arguments, (1) the state itself, (2) and (3) $J_z$ and $J_y$ respectivelly based on the representation of the state

# %%
i = 4
phi = i*pi/6
density = generateMap(eig((cos(phi)*s_x(17)+sin(phi)*s_y(17))^2)[2][:,1],s_z(17),s_y(17),40);

# %% [markdown]
# Create the map

# %%
fig = figure()
fig[:set_size_inches](5, 5)
ax = axes([0,0,1.,1.], frameon=false)
ax[:set_axis_off]()

ax[:get_xaxis]()[:set_visible](false)
ax[:get_yaxis]()[:set_visible](false)

fig[:add_axes](ax)
ax[:imshow](density,cmap="viridis", interpolation="bilinear", origin="upper", vmin=0
)
ax[:margins](0,0)
savefig("blochMap.png", bbox_inches="tight", transparent=true, pad_inches=0)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa35163d190>)

# %%
localPath = pwd()
run(`blender -b --verbose -1 $localPath/blochSphere.blend -o blochSphere_# -E CYCLES -F PNG -x 1  -f 1 > rendering.log`);
# Out:
# Color management: using fallback mode for management
# Read new prefs: /home/iapellaniz/.config/blender/2.76/config/userpref.blend
# read blend: /home/iapellaniz/Physics/PhD/Julia/Plots4Thesis/assats/blochSphere.blend
# Fra:1 Mem:21.41M (0.00M, Peak 63.76M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Point
# Fra:1 Mem:21.41M (0.00M, Peak 63.76M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Camera
# Fra:1 Mem:21.41M (0.00M, Peak 63.76M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Axises
# Fra:1 Mem:21.41M (0.00M, Peak 63.76M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Lamp
# Fra:1 Mem:21.41M (0.00M, Peak 63.76M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | wireframe
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.11 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | UVsphere
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.11 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | ecuatorRing
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.11 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Initializing
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.11 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.11 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Waiting for render to start
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.11 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Scene
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.11 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Shaders
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.21 | Mem:0.01M, Peak:0.01M | Scene, RenderLayer | Updating Background
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.21 | Mem:0.01M, Peak:0.01M | Scene, RenderLayer | Updating Camera
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.21 | Mem:0.01M, Peak:0.01M | Scene, RenderLayer | Updating Objects
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.21 | Mem:0.01M, Peak:0.01M | Scene, RenderLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.21 | Mem:0.01M, Peak:0.01M | Scene, RenderLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.21 | Mem:0.01M, Peak:0.01M | Scene, RenderLayer | Updating Meshes Flags
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.21 | Mem:0.01M, Peak:0.01M | Scene, RenderLayer | Updating Meshes
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.21 | Mem:0.01M, Peak:0.01M | Scene, RenderLayer | Updating Mesh | Computing normals
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.22 | Mem:0.01M, Peak:0.01M | Scene, RenderLayer | Updating Mesh | Copying Mesh to device
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.22 | Mem:5.68M, Peak:5.68M | Scene, RenderLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.22 | Mem:5.69M, Peak:5.69M | Scene, RenderLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.22 | Mem:6.42M, Peak:6.42M | Scene, RenderLayer | Updating Scene BVH | Building
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.22 | Mem:6.42M, Peak:6.42M | Scene, RenderLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.38 | Mem:6.42M, Peak:6.42M | Scene, RenderLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.39 | Mem:6.42M, Peak:6.42M | Scene, RenderLayer | Updating Scene BVH | Packing BVH nodes
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:6.42M, Peak:6.42M | Scene, RenderLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:19.35M, Peak:19.35M | Scene, RenderLayer | Updating Objects Flags
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:19.35M, Peak:19.35M | Scene, RenderLayer | Updating Images
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:19.35M, Peak:19.35M | Scene, RenderLayer | Updating Images | Loading blochMap.png
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:19.82M, Peak:19.82M | Scene, RenderLayer | Updating Camera Volume
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:19.82M, Peak:19.82M | Scene, RenderLayer | Updating Hair Systems
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:19.82M, Peak:19.82M | Scene, RenderLayer | Updating Hair settings | Copying Hair settings to device
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:19.82M, Peak:19.82M | Scene, RenderLayer | Updating Lookup Tables
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:20.07M, Peak:20.07M | Scene, RenderLayer | Updating Lights
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:20.07M, Peak:20.07M | Scene, RenderLayer | Updating Lights | Computing distribution
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:20.07M, Peak:20.07M | Scene, RenderLayer | Updating Particle Systems
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:20.07M, Peak:20.07M | Scene, RenderLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:20.07M, Peak:20.07M | Scene, RenderLayer | Updating Film
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:20.07M, Peak:20.07M | Scene, RenderLayer | Updating Integrator
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:20.11M, Peak:20.11M | Scene, RenderLayer | Updating Lookup Tables
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:20.11M, Peak:20.11M | Scene, RenderLayer | Updating Baking
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:20.11M, Peak:20.11M | Scene, RenderLayer | Updating Device | Writing constant memory
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.42 | Mem:20.11M, Peak:20.11M | Scene, RenderLayer | Path Tracing Tile 0/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.43 | Mem:20.53M, Peak:20.53M | Scene, RenderLayer | Path Tracing Tile 3/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.43 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 4/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.52 | Remaining:00:08.19 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 5/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.59 | Remaining:00:04.82 | Mem:20.62M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 6/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.62 | Remaining:00:03.92 | Mem:20.62M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 7/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.67 | Remaining:00:03.20 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 8/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.72 | Remaining:00:02.96 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 9/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:04.83 | Remaining:00:03.12 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 10/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:05.12 | Remaining:00:03.71 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 11/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:05.51 | Remaining:00:04.23 | Mem:20.62M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 12/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:05.57 | Remaining:00:03.77 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 13/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:05.82 | Remaining:00:03.78 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 14/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:05.95 | Remaining:00:03.80 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 15/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:06.80 | Remaining:00:04.37 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 16/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:07.55 | Remaining:00:04.87 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 17/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:07.79 | Remaining:00:04.99 | Mem:20.62M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 18/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:07.87 | Remaining:00:04.51 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 19/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:08.05 | Remaining:00:04.13 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 20/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:08.38 | Remaining:00:04.16 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 21/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:09.20 | Remaining:00:03.95 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 22/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:09.32 | Remaining:00:03.93 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 23/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:09.85 | Remaining:00:03.99 | Mem:20.62M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 24/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:09.93 | Remaining:00:03.58 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 25/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:10.04 | Remaining:00:03.18 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 26/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:10.20 | Remaining:00:03.08 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 27/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:10.61 | Remaining:00:02.72 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 28/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.18 | Remaining:00:02.36 | Mem:20.67M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 29/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.48 | Remaining:00:01.93 | Mem:20.62M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 30/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.55 | Remaining:00:01.60 | Mem:20.62M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 31/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.58 | Remaining:00:01.41 | Mem:20.56M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 32/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.61 | Remaining:00:01.22 | Mem:20.56M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 33/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.66 | Remaining:00:00.81 | Mem:20.56M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 34/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.68 | Remaining:00:00.64 | Mem:20.56M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 35/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.71 | Remaining:00:00.53 | Mem:20.48M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 36/36
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.74 | Remaining:00:00.13 | Mem:20.34M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 36/36, Sample 18/50
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.77 | Remaining:00:00.02 | Mem:20.25M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 36/36, Sample 45/50
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.94 | Mem:20.11M, Peak:20.67M | Scene, RenderLayer | Path Tracing Tile 36/36, Sample 50/50
# Fra:1 Mem:21.41M (0.00M, Peak 78.11M) | Time:00:11.94 | Mem:20.11M, Peak:20.67M | Scene, RenderLayer | Finished
# Fra:1 Mem:21.40M (0.00M, Peak 78.11M) | Time:00:11.94 | Sce: Scene Ve:0 Fa:0 La:0
# Saved: blochSphere_1.png
#  Time: 00:11.96 (Saving: 00:00.02)
#
# read blend: /home/iapellaniz/Physics/PhD/Julia/>
# Warning: Unable to open '/home/iapellaniz/Physics/PhD/Julia/>': No such file or directory
#
# Blender quit
# LoadError: failed process: Process(`blender -b --verbose -1 /home/iapellaniz/Physics/PhD/Julia/Plots4Thesis/assats/blochSphere.blend -o blochSphere_# -E CYCLES -F PNG -x 1 -f 1 > rendering.log`, ProcessExited(1)) [1]
# while loading In[25], in expression starting on line 2

# %%
fig = figure()
fig[:set_size_inches](2.5, 2.5)
ax = axes([0,0,1.,1.], frameon=false)
ax[:set_axis_off]()

ax[:get_xaxis]()[:set_visible](false)
ax[:get_yaxis]()[:set_visible](false)

imshow(imread("blochSphere_1.png"),interpolation="bilinear")
println("Your PNG image is ready! 360x360 PNG Bloch sphere")
# Out:
# Your PNG image is ready! 360x360 PNG Bloch sphere
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa35160e110>)
